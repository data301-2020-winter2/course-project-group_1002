# %%
# preparing files for tableau 
# breaking them into periods

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from scripts import project_functions # This is called a relative import
df_main = project_functions.load_and_process('../../data/raw/data.csv')


data=df_main.loc[(df_main['year']>=2001)]
data.to_csv('../../data/processed/data_period3.csv')

# %%
data=df_main.loc[(df_main['year']>=1951)&(df_main['year']<=2000)]
data.to_csv('../../data/processed/data_period2.csv')

# %%
data=df_main.loc[df_main['year']<=1950]
data.to_csv('../../data/processed/data_period1.csv')

# %%
data
# Out:
#         acousticness                                            artists  \
# 0              0.991                                    ['Mamie Smith']
# 20300          0.496  ['ST', '98', '1920Johnny', 'Barracuda', 'Nikla...
# 20299          0.996                               ['Francisco Canaro']
# 20298          0.995                                  ['Bonheur Alice']
# 20297          0.280  ['ST', '1920Johnny', '98', 'Barracuda', 'Brbk'...
# ...              ...                                                ...
# 112526         0.985  ['Pyotr Ilyich Tchaikovsky', 'Gregor Piatigors...
# 112525         0.816                               ['Эрнест Хемингуэй']
# 112522         0.991                                     ['Geeta Dutt']
# 112524         0.989                               ['Soula Karagiorgi']
# 112521         0.920                                    ['Unspecified']
#
#         danceability  duration_ms  energy  explicit  instrumentalness  key  \
# ...
