# %% [markdown]
# # Milestone 1

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read-in dataset （import first）

# %%
# data_name = (['data', 'data_w_genres', 'data_by_artist',
#              'data_by_genres', 'data_by_year'])

# def add_file(string):
#     string = pd.read_csv('../../data/processed/data/' + string + ".csv")
#     return string
    
# for name in data_name:
#     add_file(name)

# Before DRY Principle:

data = pd.read_csv('../../data/processed/data/data.csv')
data_w_genres = pd.read_csv('../../data/processed/data/data_w_genres.csv')
data_by_artist = pd.read_csv('../../data/processed/data/data_by_artist.csv')
data_by_genres = pd.read_csv('../../data/processed/data/data_by_genres.csv')
data_by_year = pd.read_csv('../../data/processed/data/data_by_year.csv')

# %% [markdown]
# ## Showing the data

# %%
data.head()
# data_w_genres.head()
# data_by_artist.head()
# data_by_genres.head()
# data_by_year.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# ...

# %% [markdown]
# ## Statistics

# %%
# Dimension
print(' ')
print('1. The dimension is: ')
print(data.shape)
print(' ')
print('-------')
print(' ')

# Statistics
print('2. The statistic info: ')
data.describe()
# Out:
#
# 1. The dimension is:
# (174389, 19)
#
# -------
#
# 2. The statistic info:
#         acousticness   danceability   duration_ms         energy  \
# count  174389.000000  174389.000000  1.743890e+05  174389.000000
# mean        0.499228       0.536758  2.328100e+05       0.482721
# std         0.379936       0.176025  1.483958e+05       0.272685
# min         0.000000       0.000000  4.937000e+03       0.000000
# 25%         0.087700       0.414000  1.661330e+05       0.249000
# 50%         0.517000       0.548000  2.057870e+05       0.465000
# 75%         0.895000       0.669000  2.657200e+05       0.711000
# max         0.996000       0.988000  5.338302e+06       1.000000
#
#             explicit  instrumentalness            key       liveness  \
# count  174389.000000     174389.000000  174389.000000  174389.000000
# mean        0.068135          0.197252       5.205305       0.211123
# std         0.251978          0.334574       3.518292       0.180493
# ...

# %% [markdown]
# ## Sorting

# %%
# Reusable functions
def sort_descending(string):
    return data.sort_values(by=string, ascending=False)

def sort_ascending(string):
    return data.sort_values(by=string, ascending=True)
    
    
# By Popularity (descending)
sort_descending('popularity')

# By Valence (descending)
# sort_descending('valence')

# By Loudness (descending)
# sort_descending('loudness')

# By Liveness (descending)
# sort_descending('liveness')

# By Key (ascending)
# sort_ascending('key')

# By Energy (ascending)
#sort_descending('energy')
# Out:
#         acousticness                                            artists  \
# 20062          0.721                                 ['Olivia Rodrigo']
# 19862          0.221                          ['24kGoldn', 'iann dior']
# 19866          0.468                                  ['Ariana Grande']
# 19886          0.401                       ['Bad Bunny', 'Jhay Cortez']
# 19976          0.212                                        ['KAROL G']
# ...              ...                                                ...
# 63064          0.982                                 ['Tarun Banerjee']
# 63063          0.994                               ['Georges Derveaux']
# 63062          0.154                               ['Эрнест Хемингуэй']
# 63061          0.958  ['Hector Berlioz', 'Concertgebouworkest', 'Edu...
# 174388         0.239                                      ['Roger Fly']
#
#         danceability  duration_ms  energy  explicit                      id  \
# ...

# %% [markdown]
# ## Frequency Table

# %%
# How many songs each artists upload to spotify
data['artists'].value_counts()
# Out:
# ['Tadeusz Dolega Mostowicz']                                                                                                                  1281
# ['Эрнест Хемингуэй']                                                                                                                          1175
# ['Эрих Мария Ремарк']                                                                                                                         1062
# ['Francisco Canaro']                                                                                                                           951
# ['Ignacio Corsini']                                                                                                                            624
#                                                                                                                                               ...
# ...
