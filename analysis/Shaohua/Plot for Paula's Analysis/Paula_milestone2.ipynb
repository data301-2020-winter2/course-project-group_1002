# %% [markdown]
# # Task 1: Introduction to Markdown

# %% [markdown]
# ## Trying out Latex and other commands (bold, italic)

# %% [markdown]
# **Question 7.8.  Show that there exists no rational number $x$ such that $x^2 = 5$.**   *Hint: Use the fact from Ex 7.7.*
#
#
# **Fact from Ex 7.7.** If $m$ is an integer such that $m^2$ is divisible by $5$, then $m$ must be divisible by $5$
#
#
#
#
# **Proof.** We argue by contradiction.
#
# Suppose to the contrary that there exists $x \in \mathbb{Q}$ such that $x^2 =5$, that is,
#
#
# $ x = \frac{m}{n}$  where $m\in \mathbb{Z}$ and $n\in \mathbb{Z} \setminus \{0\}$
#
#
# and where we assume that the fraction is in lowest terms (all common factors
# except for $\pm 1$ are cancelled out).  Then $5=x^2=m^2/n^2$ and so
#
#
# $5n^2=m^2$
#
#
# This means that $m^2$ is divisible by 5.  By the **Fact from Ex 7.7.**, $m$ must be divisible by $5$.  So, we can write $m = 5k$ where $k$ is an integer.
#
# But then the equality  $5n^2=m^2$ turns into $5n^2=(5k)^2=25k^2=5(5k^2)$.  So, we have $n^2=5k^2$ and thus $n^2$ is divisible by 5.  Again, by the **Fact from Ex 7.7.**, we deduce that $n$ must be divisible by $5$. We then write $n = 5l$, for some integer $l$.
#
# However, this leads to a contradiction since $m$ and $n$ now have a common factor which is 5.
#
# Hence, there exists no rational number $x$ such that $x^2 = 5$. $\blacksquare$

# %% [markdown]
# ---
# ## Lists

# %% [markdown]
# ### Unordered

# %% [markdown]
# My Top 3 Vocalists
#
# - Patrick Fiori
# - KYUHYUN
# - Zhou Shen

# %% [markdown]
# ### Ordered

# %% [markdown]
# Top 3 shows:
#
# 1. A
#
# 2. B
#
# 3. C

# %% [markdown]
# ---
# ## An Orwell Quote

# %% [markdown]
# > Perhaps one did not want to be loved so much as to be understood.

# %% [markdown]
# # Task 3. Method Chaining and Python Programs

# %% [markdown]
# ### Step 2: Testing function

# %%
import pandas as pd
import numpy as np
import seaborn as sns


def load_and_process(url):
    #load
    data = pd.read_csv(url)
    
    #clean
    df = (data.
            dropna().
            reset_index().
            drop(columns={'index','release_date','id', 'count'}, axis=1, errors='ignore')  
         )
    
    #sort by year if it exists
    if 'year' in data.columns:
        df = df.sort_values(by='year')

    return df

# %%
data = load_and_process('../../data/raw/data.csv')
data
# Out:
#         acousticness                                            artists  \
# 0             0.9910                                    ['Mamie Smith']
# 20300         0.4960  ['ST', '98', '1920Johnny', 'Barracuda', 'Nikla...
# 20299         0.9960                               ['Francisco Canaro']
# 20298         0.9950                                  ['Bonheur Alice']
# 20297         0.2800  ['ST', '1920Johnny', '98', 'Barracuda', 'Brbk'...
# ...              ...                                                ...
# 126778        0.0280                                ['BeatStrumentalz']
# 126777        0.1580                               ['Galantis', 'JVKE']
# 126776        0.0898                              ['Vyacheslav Sketch']
# 126790        0.0175                                       ['TON Jayy']
# 143165        0.5360                                     ['Jhené Aiko']
#
#         danceability  duration_ms  energy  explicit  instrumentalness  key  \
# ...

# %% [markdown]
# Note: No null values found

# %%
#load the rest
data_by_artist = load_and_process('../../data/raw/data_by_artist.csv')
data_by_genres =  load_and_process('../../data/raw/data_by_genres.csv')
data_by_year = load_and_process('../../data/raw/data_by_year.csv')
data_w_genres = load_and_process('../../data/raw/data_w_genres.csv')


#data_by_artist 
#data_by_genres
#data_by_year
data_w_genres
# Out:
#                                                  artists  acousticness  \
# 0                       "Cats" 1981 Original London Cast      0.598500
# 1                              "Cats" 1983 Broadway Cast      0.862538
# 2            "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3         "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4      "Joseph And The Amazing Technicolor Dreamcoat"...      0.510714
# ...                                                  ...           ...
# 32534                                                김효근      0.939000
# 32535                                                 나율      0.717000
# 32536                                                미스티      0.416000
# 32537                  시온 Zion & 한해 Hanhae of 팬텀 Phantom      0.288000
# 32538                                                조정현      0.568000
#
#        danceability    duration_ms    energy  instrumentalness  liveness  \
# ...

# %% [markdown]
# ---
# # Task 4: Conduct an Exploratory Data Analysis (EDA) on your dataset

# %% [markdown]
# Each EDA should:
#
# - Involve at least two columns/features of your dataset
#
# - At least three useful visualizations created by you (the more the merrier (within reason)!)
#
# - Some notes and commentary to help others see observations you find interesting.
#
# - counts of columns, limits, ranges, understand the data distribution, and a cursory look at the relationships between the columns

# %%
sns.set_theme(style="ticks",
              font_scale=1.5, 
             )

# %% [markdown]
# ## Main dataframe analysis

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from scripts import project_functions # This is called a relative import
df_main = project_functions.load_and_process('../../data/raw/data.csv')

#load the rest
data_by_artist = project_functions.load_and_process('../../data/raw/data_by_artist.csv')
data_by_genres =  project_functions.load_and_process('../../data/raw/data_by_genres.csv')
data_by_year = project_functions.load_and_process('../../data/raw/data_by_year.csv')
data_w_genres = project_functions.load_and_process('../../data/raw/data_w_genres.csv')


#data_by_artist 
#data_by_genres
#data_by_year
#data_w_genres
df_main
# Out:
#         acousticness                                            artists  \
# 0             0.9910                                    ['Mamie Smith']
# 20300         0.4960  ['ST', '98', '1920Johnny', 'Barracuda', 'Nikla...
# 20299         0.9960                               ['Francisco Canaro']
# 20298         0.9950                                  ['Bonheur Alice']
# 20297         0.2800  ['ST', '1920Johnny', '98', 'Barracuda', 'Brbk'...
# ...              ...                                                ...
# 126778        0.0280                                ['BeatStrumentalz']
# 126777        0.1580                               ['Galantis', 'JVKE']
# 126776        0.0898                              ['Vyacheslav Sketch']
# 126790        0.0175                                       ['TON Jayy']
# 143165        0.5360                                     ['Jhené Aiko']
#
#         danceability  duration_ms  energy  explicit  instrumentalness  key  \
# ...

# %% [markdown]
# ## Size of the dataframes

# %%
#data_by_artist.shape 
#data_by_genres.shape
#data_by_year.shape
data_w_genres.shape
#df_main.shape
# Out:
# (32539, 15)

# %% [markdown]
# + **Main file**: 174389 rows, 17 columns
# + **data_by_artist**: 32539 rows, 14 columns
# + **data_by_genres**: 3232 rows, 14 columns
# + **data_by_year**: 102 rows, 14 columns
# + **data_w_genres**: 32539 rows, 15 columns

# %% [markdown]
# ## Describe

# %%
df_main.drop(columns= {'duration_ms', 'explicit','key','year','mode'}).describe()
# drop the less meaningful columns
# Min and max values are within range
# Out:
#         acousticness   danceability         energy  instrumentalness  \
# count  174389.000000  174389.000000  174389.000000     174389.000000
# mean        0.499228       0.536758       0.482721          0.197252
# std         0.379936       0.176025       0.272685          0.334574
# min         0.000000       0.000000       0.000000          0.000000
# 25%         0.087700       0.414000       0.249000          0.000000
# 50%         0.517000       0.548000       0.465000          0.000524
# 75%         0.895000       0.669000       0.711000          0.252000
# max         0.996000       0.988000       1.000000          1.000000
#
#             liveness       loudness     popularity    speechiness  \
# count  174389.000000  174389.000000  174389.000000  174389.000000
# mean        0.211123     -11.750865      25.693381       0.105729
# std         0.180493       5.691591      21.872740       0.182260
# min         0.000000     -60.000000       0.000000       0.000000
# ...

# %%
df_main.dtypes
# Out:
# acousticness        float64
# artists              object
# danceability        float64
# duration_ms           int64
# energy              float64
# explicit              int64
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# mode                  int64
# name                 object
# popularity            int64
# speechiness         float64
# tempo               float64
# valence             float64
# year                  int64
# dtype: object

# %% [markdown]
# ## Notes on the variables (see https://developer.spotify.com/documentation/web-api/reference/#objects-index)
#
# ### Tracks:
#
# - **acousticness**:    A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# - **artists**:   The artists who performed the track. This is stored as an array.
# - **danceability**: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# - **duration_ms**: The track length in milliseconds.
# - **energy**: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
# - **explicit**: Whether or not the track has explicit lyrics ( `true` = yes it does; `false` = no it does not OR unknown).
# - **instrumentalness**: Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
# - **key**:The key the track is in. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on.
# - **liveness**: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
# - **loudness**:The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db
# - **mode**:Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
# - **speechiness**: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
# - **tempo**: The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
# - **valence**: A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
# - **year**:
# - **popularity**: The popularity of the track. The value will be between 0 and 100, with 100 being the most popular.
# The popularity is calculated by algorithm and is based, in the most part, on the total number of plays the track has had and how recent those plays are.
# Generally speaking, songs that are being played a lot now will have a higher popularity than songs that were played a lot in the past. Duplicate tracks (e.g. the same track from a single and an album) are rated independently. Artist and album popularity is derived mathematically from track popularity. Note that the popularity value may lag actual popularity by a few days: the value is not updated in real time.
#
# ### Artist
#
# - **genres**: A list of the genres the artist is associated with. For example: "Prog Rock" , "Post-Grunge". (If not yet classified, the array is empty.)
# - **popularity**: The popularity of the artist. The value will be between 0 and 100, with 100 being the most popular. The artist’s popularity is calculated from the popularity of all the artist’s tracks.

# %% [markdown]
# ## Visualisations etc

# %%
import os
import sys

import pandas_profiling as pdp

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from scripts import project_functions # This is called a relative import

# %%
# pandas profiling
#data_by_year.profile_report()

# %% [markdown]
# Notes on `data_by_year` (the values are mean values of the data for each year):
#
# - No duplicate values
#
# - `tempo` is highly correlated with `energy` (unsurprisingly)
#
# - Interesting correlations:
#      - `Year` is correlated with `acousticness`
#      - Both `energy` and `loudness` are correlated with `year`  (also suggests that `energy` and `loudness` are related)
#      - more `energy` does not mean that the song is more 'danceable'
#      - 'key' and `valence` are not related
#
# - `acousticness` seems to be negatively correlated with `energy`
# - `acousticness` seems to be decreasing over the years while `energy`, `loudness` and `tempo` have been increasing.
# -  The duration of tracks seems to have increased over the years, but there is no significant correlation.
#
# - Energetic songs have become more and more popular over the years
#
# - The `valence` (positivity) of songs has experienced a significant decrease over the last 20 years

# %%
#data_by_genres.profile_report()

# %% [markdown]
# ### Analysing popularity trends

# %%
popularity_above90 = df_main[df_main['popularity']>90]
popularity_above90.head()
# Out:
#        acousticness                                            artists  \
# 19470         0.483                                            ['Sia']
# 19670         0.122                                   ['Harry Styles']
# 39236         0.168                             ['Joel Corry', 'MNEK']
# 39252         0.414                                         ['Tiësto']
# 39424         0.180  ['Manuel Turizo', 'Rauw Alejandro', 'Myke Towe...
#
#        danceability  duration_ms  energy  explicit  instrumentalness  key  \
# 19470         0.716       165907   0.512         0          0.000000    1
# 19670         0.548       174000   0.816         0          0.000000    0
# 39236         0.734       166028   0.874         0          0.000011    8
# 39252         0.798       164000   0.620         0          0.019200    8
# 39424         0.736       216107   0.632         0          0.000000   11
#
#        liveness  loudness  mode                       name  popularity  \
# ...

# %%
import pandas_profiling as pdp
#popularity_above90.profile_report()

# %% [markdown]
# - High Popularity related with low instrumentalness

# %% [markdown]
# ### Testing conversion from string to list

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from scripts import project_functions
popularity_above90 = project_functions.convert_and_explode('artists', popularity_above90)
popularity_above90
# Out:
# /Users/jiangshaohua/Desktop/UBC/2020 Winter Term 2/COSC 301/Group Project/Milestone 1 & 2/course-project-group_1002/analysis/scripts/project_functions.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[column] = dataframe[column].astype(str).apply(literal_eval)
#        acousticness              artists  danceability  duration_ms  energy  \
# 19470       0.48300                  Sia         0.716       165907   0.512
# 19670       0.12200         Harry Styles         0.548       174000   0.816
# 39236       0.16800           Joel Corry         0.734       166028   0.874
# 39236       0.16800                 MNEK         0.734       166028   0.874
# 39252       0.41400               Tiësto         0.798       164000   0.620
# ...

# %%
popularity_above90['artists'].value_counts() #of all time
# Out:
# Justin Bieber          3
# Bad Bunny              3
# Jhay Cortez            2
# BTS                    2
# Myke Towers            2
# DaBaby                 2
# Pop Smoke              2
# Ariana Grande          2
# Manuel Turizo          1
# benny blanco           1
# Lil Baby               1
# Conan Gray             1
# MNEK                   1
# Shawn Mendes           1
# SZA                    1
# Harry Styles           1
# Joel Corry             1
# CJ                     1
# Rauw Alejandro         1
# KAROL G                1
# Sia                    1
# Megan Thee Stallion    1
# 24kGoldn               1
# iann dior              1
# Billie Eilish          1
# Cardi B                1
# Tiësto                 1
# Juhn                   1
# Tate McRae             1
# Roddy Ricch            1
# ROSALÍA                1
# Olivia Rodrigo         1
# Lil Nas X              1
# Boza                   1
# The Kid LAROI          1
# Name: artists, dtype: int64

# %% [markdown]
# So the top artists were:
#
# - Bad Bunny
# - Justin Bieber
# - Pop Smoke
# - BTS
# - Myke Towers
# - DaBaby
# - Ariana Grande
# - Jhay Cortez

# %% [markdown]
# ## Looking at yearly trends more closely

# %%
data_by_year = data_by_year.drop(columns={'key', 'mode'})
data_by_year
# the averages of the key and mode make no sense
# Out:
#      year  acousticness  danceability    duration_ms    energy  \
# 0    1920      0.631242      0.515750  238092.997135  0.418700
# 1    1921      0.862105      0.432171  257891.762821  0.241136
# 2    1922      0.828934      0.575620  140135.140496  0.226173
# 3    1923      0.957247      0.577341  177942.362162  0.262406
# 4    1924      0.940200      0.549894  191046.707627  0.344347
# ..    ...           ...           ...            ...       ...
# 97   2017      0.207413      0.580475  243402.249536  0.686392
# 98   2018      0.233836      0.602731  227073.140015  0.659552
# 99   2019      0.261344      0.603101  225463.326320  0.629781
# 100  2020      0.202303      0.605285  218977.482767  0.674247
# 101  2021      0.340253      0.652488  222760.028261  0.578896
#
#      instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0            0.354219  0.216049 -12.654020     0.082984  113.226900  0.498210
# ...

# %%
data_by_year['year'].max()
# Out:
# 2021

# %%
import seaborn as sns

pair = sns.pairplot(data_by_year)
pair

# %% [markdown]
# Some observations:
#
# - Significant drop in valence in last 20 years
# - Preference for fast tempo
# - Speechiness has not changed much in 100 years.  By looking at the `speechiness` vs `popularity` graph, we can see that, over than being popular in the 1920s, speechiness has never been much favored in a track.
# - Loudness and energy has an almost linear increase over the years
# - Acousticness is not preferred anymore

# %%
# hist = sns.displot(data_by_year, x = "year", hue = "Status Mission", multiple="stack", bins = 18, aspect = 2)

# hist.fig.suptitle('Reported Space launches by mission status',fontsize = 16)
# plt.ylabel('Number of launches')
# hist

# %% [markdown]
# ### Looking at periods

# %% [markdown]
# **1. 1920 - 1950. The period of transition from traditional to modern forms of music**

# %%
# find max popularity for this period
temp = df_main.loc[(df_main['year']<=1950)]
temp['popularity'].max()
# Out:
# 80

# %%
#look at the 75th percentile 

temp = df_main.loc[(df_main['year']<=1950)&(df_main['popularity']>=60)]
temp1 = temp.drop(columns={'duration_ms', 'key', 'mode', 'year', 'popularity'}).describe() #save in a dataframe for later use
temp1
# Out:
#        acousticness  danceability     energy  explicit  instrumentalness  \
# count     12.000000     12.000000  12.000000      12.0         12.000000
# mean       0.849583      0.520250   0.226433       0.0          0.107882
# std        0.112426      0.178683   0.122255       0.0          0.280087
# min        0.646000      0.156000   0.012800       0.0          0.000000
# 25%        0.791750      0.455750   0.158750       0.0          0.000000
# 50%        0.857500      0.502000   0.218000       0.0          0.000000
# 75%        0.937000      0.632000   0.338000       0.0          0.001148
# max        0.994000      0.834000   0.413000       0.0          0.937000
#
#         liveness   loudness  speechiness       tempo    valence
# count  12.000000  12.000000    12.000000   12.000000  12.000000
# mean    0.258867 -14.203083     0.052708  139.509333   0.602667
# std     0.173473   7.872511     0.025931   39.991085   0.277402
# ...

# %% [markdown]
# Notes (based on mean):
#
# - High `acousticness`
# - low `energy`
# - No `explicit` content(!)
# - Low `loudness`
# - Low `speechiness`
# - Lots of variation in tempo
# - High `valence`

# %%
temp = temp.sort_values(by='popularity',ascending=False) #sort by popularity
temp = project_functions.convert_and_explode('artists', temp)   #apply explode to count values
temp
# Out:
#       acousticness                             artists  danceability  \
# 4262         0.673                         Bing Crosby         0.317
# 4262         0.673                   Ken Darby Singers         0.317
# 4262         0.673  John Scott Trotter & His Orchestra         0.317
# 4662         0.970                        Judy Garland         0.156
# 5262         0.799                          Gene Autry         0.834
# 5663         0.994                          Erik Satie         0.469
# 5663         0.994                  Philippe Entremont         0.469
# 5662         0.926                         Bing Crosby         0.641
# 5662         0.926                 The Andrews Sisters         0.641
# 5263         0.883                          Gene Autry         0.629
# 4862         0.646                         Bing Crosby         0.500
# 4862         0.646                 The Andrews Sisters         0.500
# 5664         0.851                         Bing Crosby         0.627
# ...

# %%
temp['artists'].value_counts()
# Out:
# Bing Crosby                           5
# The Andrews Sisters                   3
# Gene Autry                            3
# Doris Day                             1
# Judy Garland                          1
# Eddie Heywood                         1
# Frank DeVol & His Orchestra           1
# Ken Darby Singers                     1
# Erik Satie                            1
# John Scott Trotter & His Orchestra    1
# Philippe Entremont                    1
# Cass County Boys                      1
# Billie Holiday                        1
# Name: artists, dtype: int64

# %% [markdown]
# Top 3 artists:
# - Bing Crosby
# - Gene Autry
# - The Andrews Sisters
#
# Also, interestingly, most of these songs are Christmas songs

# %% [markdown]
# **2. 1951 - 2000. Advent of electronic music and other novel approaches to creating music.**

# %%
# find max popularity for this period
temp = df_main.loc[(df_main['year']>=1951)&(df_main['year']<=2000)]
temp['popularity'].max()
# Out:
# 90

# %%
#look at the 75th percentile 

temp = df_main.loc[(df_main['year']>=1951)&(df_main['year']<=2000)&(df_main['popularity']>=67.5)]
temp2 = temp.drop(columns={'duration_ms', 'key', 'mode', 'year', 'popularity'}).describe() #save in a dataframe for later use
temp2
# Out:
#        acousticness  danceability       energy     explicit  instrumentalness  \
# count   1052.000000   1052.000000  1052.000000  1052.000000       1052.000000
# mean       0.273401      0.584107     0.622799     0.066540          0.028100
# std        0.272858      0.159296     0.214116     0.249342          0.110231
# min        0.000018      0.149000     0.005320     0.000000          0.000000
# 25%        0.036400      0.474750     0.467750     0.000000          0.000000
# 50%        0.182000      0.588500     0.637000     0.000000          0.000031
# 75%        0.448250      0.698000     0.804000     0.000000          0.001510
# max        0.994000      0.956000     0.997000     1.000000          0.912000
#
#           liveness     loudness  speechiness        tempo      valence
# count  1052.000000  1052.000000  1052.000000  1052.000000  1052.000000
# mean      0.172207    -8.954581     0.060373   120.095817     0.606606
# ...

# %% [markdown]
# Notes (based on mean):
#
# - `Acousticness` has significantly decreased
# - High `energy`
# - `explicit` content becoming more accepted
# - `loudness` is still quite low
# - `valence` unchanged

# %%
#Look at top 15
temp = temp.sort_values(by='popularity',ascending=False) #sort by popularity
temp.head(15)
# Out:
#        acousticness                                     artists  danceability  \
# 14662       0.16400                            ['Mariah Carey']         0.336
# 8662        0.61400                              ['Brenda Lee']         0.589
# 11262       0.06440                           ['Fleetwood Mac']         0.828
# 15862       0.00239                                ['Coldplay']         0.429
# 8462        0.76600                           ['Andy Williams']         0.240
# 7262        0.64300                             ['Bobby Helms']         0.754
# 7662        0.91200                             ['Dean Martin']         0.451
# 14663       0.90300     ['Frank Sinatra', 'B. Swanson Quartet']         0.652
# 11863       0.01100                                   ['AC/DC']         0.310
# 12462       0.54300                              ['The Police']         0.820
# 12864       0.01800                                    ['a-ha']         0.573
# ...

# %%
temp = project_functions.convert_and_explode('artists', temp)   #apply explode to count values
temp['artists'].value_counts()
# Out:
# The Beatles                     18
# Michael Jackson                 12
# Frank Sinatra                   12
# Elton John                      12
# Fleetwood Mac                   11
#                                 ..
# Bette Midler                     1
# A Tribe Called Quest             1
# Randy Newman                     1
# Crosby, Stills, Nash & Young     1
# Buena Vista Social Club          1
# Name: artists, Length: 575, dtype: int64

# %% [markdown]
# Top artists (count of popular songs):
#
# - The Beatles
# - Frank Sinatra
# - Michael Jackson
# - Elton John
# - Fleetwood Mac
#
# However, these artists are not the most popular of this period.
# Some of the top tracks and their respective artists are:
#
# - 'All I want for Christmas is You' - Mariah Carey
# - 'Rockin' Around The Christmas Tree' - Brenda Lee
# - 'Dreams - 2004 Remaster' - Fleetwood Mac
# - 'Yellow' - Coldplay
# - 'It's the Most Wonderful Time of the Year' - Andy Williams

# %% [markdown]
# **3. 2001 - 2021. The present.**

# %%
# find max popularity for this period
temp = df_main.loc[(df_main['year']>=2001)]
temp['popularity'].max()
# Out:
# 100

# %%
#look at the 75th percentile 

temp = df_main.loc[(df_main['year']>=2001)&(df_main['popularity']>=75)]
temp3 = temp.drop(columns={'duration_ms', 'key', 'mode', 'year', 'popularity'}).describe() #save in a dataframe for later use
temp3
# Out:
#        acousticness  danceability      energy     explicit  instrumentalness  \
# count   1577.000000   1577.000000  1577.00000  1577.000000       1577.000000
# mean       0.248292      0.661119     0.62265     0.395054          0.017513
# std        0.264488      0.146725     0.18067     0.489017          0.100959
# min        0.000010      0.000000     0.00002     0.000000          0.000000
# 25%        0.037100      0.567000     0.51600     0.000000          0.000000
# 50%        0.146000      0.676000     0.63700     0.000000          0.000000
# 75%        0.390000      0.765000     0.75100     1.000000          0.000037
# max        0.985000      0.980000     0.98800     1.000000          1.000000
#
#           liveness     loudness  speechiness        tempo      valence
# count  1577.000000  1577.000000  1577.000000  1577.000000  1577.000000
# mean      0.168443    -6.521528     0.103841   120.333003     0.474220
# ...

# %% [markdown]
# Notes (based on mean):
#
# - Low `acousticness`
# - High `energy`
# - More `explicit` content
# - More `loudness` (closer to 0 dB)
# - More `speechiness` (surprising considering the previous trends. -Rap?)
# - Lower `valence`
# - Maximum `tempo` threshold reached a new high of 220

# %%
#Look at top 15
temp = temp.sort_values(by='popularity',ascending=False) #sort by popularity
temp.head(15)
# Out:
#        acousticness                            artists  danceability  \
# 20062        0.7210                 ['Olivia Rodrigo']         0.585
# 19866        0.4680                  ['Ariana Grande']         0.737
# 19862        0.2210          ['24kGoldn', 'iann dior']         0.700
# 19976        0.2120                        ['KAROL G']         0.863
# 19886        0.4010       ['Bad Bunny', 'Jhay Cortez']         0.731
# 19928        0.0303           ['Bad Bunny', 'ROSALÍA']         0.856
# 19872        0.2130                  ['The Kid LAROI']         0.662
# 19870        0.1900                             ['CJ']         0.711
# 19868        0.2370                  ['Ariana Grande']         0.830
# 19876        0.2180                  ['Billie Eilish']         0.889
# 19878        0.6500                      ['Pop Smoke']         0.709
# 19900        0.7860                     ['Tate McRae']         0.642
# 39252        0.4140                         ['Tiësto']         0.798
# ...

# %%
temp = project_functions.convert_and_explode('artists', temp)   #apply explode to count values
temp['artists'].value_counts()
# Out:
# Juice WRLD           52
# Bad Bunny            46
# Taylor Swift         35
# Ariana Grande        32
# Drake                29
#                      ..
# John Lennon           1
# salvia palth          1
# Jessie Reyez          1
# Sasha Sloan           1
# Young Stoner Life     1
# Name: artists, Length: 844, dtype: int64

# %% [markdown]
# The top artists are:
#
# - Juice WRLD
# - Bad Bunny
# - Taylor Swift
# - Ariana Grande
# - Drake
#
# However, these artists are not the most popular of this period. Some of the top tracks and their respective artists are:
#
# - 'drivers license' - Olivia Rodrigo
# - 'positions' - Ariana Grande
# -  'Mood (feat. iann dior)' - 24kGoldn, iann dior

# %% [markdown]
# ### Summary Dataframe for this section

# %%
#create dataframe from the results in the previous section
summary_mean = (temp1.iloc[[1]].
                append(temp2.iloc[[1]], ignore_index=True).
                append(temp3.iloc[[1]], ignore_index=True)
               )

summary_mean
# Out:
#    acousticness  danceability    energy  explicit  instrumentalness  liveness  \
# 0      0.849583      0.520250  0.226433  0.000000          0.107882  0.258867
# 1      0.273401      0.584107  0.622799  0.066540          0.028100  0.172207
# 2      0.248292      0.661119  0.622650  0.395054          0.017513  0.168443
#
#     loudness  speechiness       tempo   valence
# 0 -14.203083     0.052708  139.509333  0.602667
# 1  -8.954581     0.060373  120.095817  0.606606
# 2  -6.521528     0.103841  120.333003  0.474220

# %%
#add period
summary_mean.insert(0, 'period', ['1920 - 1950','1951 - 2000','2001 - 2021'], True) 
summary_mean
# Out:
#         period  acousticness  danceability    energy  explicit  \
# 0  1920 - 1950      0.849583      0.520250  0.226433  0.000000
# 1  1951 - 2000      0.273401      0.584107  0.622799  0.066540
# 2  2001 - 2021      0.248292      0.661119  0.622650  0.395054
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence
# 0          0.107882  0.258867 -14.203083     0.052708  139.509333  0.602667
# 1          0.028100  0.172207  -8.954581     0.060373  120.095817  0.606606
# 2          0.017513  0.168443  -6.521528     0.103841  120.333003  0.474220

# %% [markdown]
# + Row 0 - First period
# + Row 1 - Second period
# + Row 2 - Third period

# %%
#plot barchart
#project_functions.bar_chart('Period', 'acousticness', summary_mean)

ax = summary_mean.plot.bar(x= 'period', y={'energy','acousticness','instrumentalness'}, rot=0, title= 'Energy, Acousticness, and instrumentalness trends')

# %%
ax2 = summary_mean.plot.bar(x= 'period', y={'explicit'}, rot=0, title= 'Trends in explicit content acceptance')

# %% [markdown]
# ## Looking at Genres

# %%
#find max popularity
data_by_genres['popularity'].max()
# Out:
# 79.0

# %%
#look at 75th percentile

temp_genre = data_by_genres[data_by_genres['popularity']>=60].sort_values(by='popularity', ascending = False)
temp_genre.head(10)
# Out:
#                   genres  acousticness  danceability    duration_ms    energy  \
# 565   chinese electropop      0.002570      0.660000  217088.000000  0.787000
# 1768  korean mask singer      0.238000      0.658000  199027.000000  0.749000
# 3213                yaoi      0.006550      0.603000  206180.000000  0.964000
# 996        dutch rap pop      0.216000      0.767000  192452.000000  0.643000
# 2544  rochester mn indie      0.034700      0.655000  205766.000000  0.487000
# 945              dong-yo      0.259000      0.829000   80927.000000  0.886000
# 44             afroswing      0.171333      0.758333  188818.333333  0.512000
# 1066        estonian pop      0.285000      0.458000  207069.000000  0.696000
# 1616               j-rap      0.096100      0.648000  327967.000000  0.904000
# 1539           irish pop      0.308600      0.474750  212684.125000  0.513625
#
#       instrumentalness  liveness  loudness  speechiness       tempo   valence  \
# ...

# %% [markdown]
# Surprisingly, Chinese electropop is the top genre.  This is followed by the 'korean mask singer' genre.  'Dutch rap indie', 'rochester mn indie' and 'dong-yo' follow closely behind.
#
# All of these genres have low acousticness, low instrumentalness, high energy and high loudness

# %% [markdown]
# ---
# # My research Questions

# %% [markdown]
# **Things to keep in mind**:
# 1. The dataset only reflects American tastes
#
# 2.
# Since the earliest track was released in 1920, we are focusing on the modern period and later. The early 20th Century marks the transition from romanticism (Tchaikovsky, Mahler, Strauss) to modernism (Schoenberg - *twelve tone*- , Debussy, Gershwin - *jazz* -).  Composers reject restrictions and transition to free form and experimentation.  The 20th Century is an era of massive technological and socio-political change where technology starts to bring new avenues to the production and distribution of music.
#
# Accroding to ClassicFM, "modernism in music was about being radical and different." The 1920s saw the birth of the *blues*, a predecessor to country music and rock n’ roll.
#
# As we enter the 21st Century, contemporary music, along with new forms of music, such as electronic music, start to surface.
#
# References:
# - https://www.classicfm.com/discover-music/periods-genres/modern/
# - https://wmich.edu/mus-gened/mus150/1500%20webbook%20modern%20artmusic/Modern%20ArtMusic.htm
#
# 3. Major events: world wars

# %% [markdown]
# **My breakdown of 'periods'**
#
# I will consider 'periods' of the modern era roughly based on the breakdown provided on the wmich.edu webpage listed above.
#
# 1. 1920 - 1950.  The period of transition from traditional to modern forms of music
# 2. 1951 - 2000.  Advent of electronic music and other novel approaches to creating music.
# 3. 2001 - 2021.  The present.

# %% [markdown]
# **Notes on analysis**
#
# - Since the dataset has its own limitations in terms of data on older tracks, for fairness, I first found out the maximum popularity for each period and then considered the 75th percentile based on that maximum value to look at characteristics of popular songs.

# %% [markdown]
# ### **RQ1: What are some factors which could predict the popularity of a track?**
#
# - Fast tempo
# - Low speechiness
# - Low acousticness
# - High `loudness` and `energy` (leading to high `danceability`)
#
# This reflects the current trends in music, where party music has more traction.

# %% [markdown]
# ### **RQ2: How have the features which made tracks popular change over the years?**

# %% [markdown]
# Combined with RQ3

# %% [markdown]
# ### **RQ3: What are the general musical trends in the specified periods?  Identify the most popular artists, and song(s) for each period.**

# %% [markdown]
# **1. 1920 - 1950. The period of transition from traditional to modern forms of music**
#
# Characteristics:
# - High `acousticness`
# - low `energy`
# - No `explicit` content(!)
# - Low `loudness`
# - Low `speechiness`
# - Lots of variation in tempo
# - High `valence`
#
# Top 3 artists:
# - Bing Crosby
# - Gene Autry
# - The Andrews Sisters
#
# Interestingly, most of the popular songs are Christmas songs.  Is this a potential limitation of the dataset?  The data might not reflect the tastes of this period,
# but rather reflect what kind of music from this period that present listeners like.

# %% [markdown]
# **2. 1951 - 2000. Advent of electronic music and other novel approaches to creating music.**
#
# Characteristics:
#
# - `Acousticness` has significantly decreased
# - High `energy`
# - `explicit` content becoming more accepted
# - `loudness` is still quite low
# - `valence` unchanged
#
# Top artists (count of popular songs):
#
# - The Beatles
# - Frank Sinatra
# - Michael Jackson
# - Elton John
# - Fleetwood Mac
#
# However, these artists are not the most popular of this period.
# Some of the top tracks and their respective artists are:
#
# - 'All I want for Christmas is You' - Mariah Carey
# - 'Rockin' Around The Christmas Tree' - Brenda Lee
# - 'Dreams - 2004 Remaster' - Fleetwood Mac
# - 'Yellow' - Coldplay
# - 'It's the Most Wonderful Time of the Year' - Andy Williams

# %% [markdown]
# **3. 2001 - 2021. The present.**
#
# Characteristics:
#
# - Low `acousticness`
# - High `energy`
# - More `explicit` content
# - More `loudness` (closer to 0 dB)
# - More `speechiness` (surprising considering the previous trends. -Rap?)
# - Lower `valence`
# - Maximum `tempo` threshold reached a new high of 220
#
# The top artists are:
#
# - Juice WRLD
# - Bad Bunny
# - Taylor Swift
# - Ariana Grande
# - Drake
#
# However, these artists are not the most popular of this period. Some of the top tracks and their respective artists are:
#
# - 'drivers license' - Olivia Rodrigo
# - 'positions' - Ariana Grande
# -  'Mood (feat. iann dior)' - 24kGoldn, iann dior

# %% [markdown]
# ### **RQ4:  Popular genres? (general trend)**

# %% [markdown]
# Surprisingly, Chinese electropop is the top genre.  This is followed by the 'korean mask singer' genre.  'Dutch rap indie', 'rochester mn indie' and 'dong-yo' follow closely behind.
#
# All of these genres have low acousticness, low instrumentalness, high energy and high loudness

# %% [markdown]
# ---
# **Conclusion:**
#
# - We are actually analysing popularity trends based on tastes of our generation, and not the tastes of the generation of a certain period.
# - Music characteristics are however more accurate as they are properties of the tracks themselves.
# - Popular music from older periods tend to be Christmas songs...
#
# - We should not forget that all of this data is only based on Spotify api data and the result of the analysis might not accurately represent the tastes of the general population
#     - Spotify is mostly used by the young generation
